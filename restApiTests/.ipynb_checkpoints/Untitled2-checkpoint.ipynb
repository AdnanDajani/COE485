# %%
import time
import os
from flask import Flask
from flask_restful import Api, Resource
import requests
import json

# %%
BASE ="http://127.0.0.1:5000/"



stat = ["green","red",'red','red']
current_light=0
delay=[1, 1, 1, 1]

while(1):
    print("delays:", delay)
    
    for i in range(4*(len(stat))):
        os.system('clear')
        print(stat)
        if(stat[current_light]=='green'):
            stat[current_light]='yellow'
            time.sleep(delay[current_light])
        
        elif(stat[current_light]=='yellow'):
            stat[current_light]='red'
            stat[(current_light+1)%len(stat)]='green'
            time.sleep(1)
            current_light=(current_light+1)%len(stat)
        
    
    
    response =requests.get(BASE+"tld"+'/2').json()
    
    print(response)
    for j in range(len(response)):
        delay[j]=response[str(j+1)]
# Out:
# delays: [1, 1, 1, 1]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': 4, '2': 4, '3': 4, '4': 4}
# delays: [4, 4, 4, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1ad485a5941d> in <module>
#      15         if(stat[current_light]=='green'):
#      16             stat[current_light]='yellow'
# ---> 17             time.sleep(delay[current_light])
#      18
#      19         elif(stat[current_light]=='yellow'):
#
# KeyboardInterrupt:
