# %%
import time
import os
from flask import Flask
from flask_restful import Api, Resource
import requests
import json

# %%
BASE ="http://127.0.0.1:5000/"



stat = ["green","red",'red','red']
current_light=0
delay=[1, 1, 1, 1]

while(1):
    print("delays:", delay)
    
    for i in range(4*(len(stat))):
        os.system('clear')
        print(stat)
        if(stat[current_light]=='green'):
            stat[current_light]='yellow'
            time.sleep(delay[current_light])
        
        elif(stat[current_light]=='yellow'):
            stat[current_light]='red'
            stat[(current_light+1)%len(stat)]='green'
            time.sleep(1)
            current_light=(current_light+1)%len(stat)
        
    
    
    response =requests.get(BASE+"tld"+'/1').json()
    
    print(response)
    for j in range(len(response)):
        delay[j]=int(response[str(j+1)])
# Out:
# delays: [1, 1, 1, 1]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# {'1': '1', '2': '2', '3': '3', '4': '4'}
# delays: [1, 2, 3, 4]
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'green', 'red']
# ['red', 'red', 'yellow', 'red']
# ['red', 'red', 'red', 'green']
# ['red', 'red', 'red', 'yellow']
# ['green', 'red', 'red', 'red']
# ['yellow', 'red', 'red', 'red']
# ['red', 'green', 'red', 'red']
# ...
